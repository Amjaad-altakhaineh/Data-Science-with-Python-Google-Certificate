# %% [markdown]
# # التنبؤ بالسلاسل الزمنية باستخدام Python
# ## نسخة الطالب للتطبيق المباشر — مع قسم Python واضح من البداية
#
# هذا الدفتر مخصص للتطبيق أثناء المحاضرة.
# خلايا الكود في نسخة الطالب **فارغة** حتى يكتب المتدربون الكود مع المدرب خطوة بخطوة.
#
# > ملاحظة مهمة: قسم Python موجود في بداية اليوم الأول تحت عنوان **Python Side / جانب Python**، قبل قراءة ملفات CSV وقبل التنبؤ.

# %% [markdown]
# ## Aim / الهدف
#
# تجهيز المتدربين لاستخدام Python وJupyter وPandas في تحليل السلاسل الزمنية وبناء نماذج تنبؤ بسيطة.
#
# ## Objectives / المخرجات التعليمية
#
# بنهاية التدريب، يتوقع أن يكون المتدرب قادراً على:
#
# 1. تشغيل خلايا Jupyter وفهم الناتج.
# 2. كتابة أوامر Python بسيطة مرتبطة بالمبيعات والبيانات.
# 3. إنشاء جداول باستخدام Pandas.
# 4. قراءة ملفات CSV.
# 5. تحويل عمود التاريخ إلى صيغة زمنية.
# 6. تنظيف القيم المفقودة والشاذة بشكل مبسط.
# 7. رسم السلسلة الزمنية وفهم الاتجاه العام.
# 8. بناء نماذج تنبؤ بسيطة.
# 9. تقييم التنبؤ باستخدام MAE وRMSE وMAPE.
# 10. تحويل التنبؤ إلى توصية عملية.
#
# **Risk Assessment:** Low

# %% [markdown]
# ## الملفات المطلوبة
#
# ضع الملفات التالية في نفس مجلد الدفتر:
#
# - `cafe_sales_timeseries_course_raw.csv`
# - `cafe_sales_timeseries_course_clean.csv`
# - `cafe_sales_by_product_examples.csv`
# - `small_week_sales_examples.csv`
#
# ## خطة الأيام الأربعة
#
# | اليوم | المحور | الهدف العملي |
# |---|---|---|
# | اليوم الأول | Python Side + Jupyter + Pandas + الرسوم | إزالة رهبة الكود وفهم الأدوات الأساسية |
# | اليوم الثاني | قراءة CSV وتجهيز السلسلة الزمنية | تحويل البيانات الخام إلى بيانات جاهزة للتحليل |
# | اليوم الثالث | نماذج تنبؤ بسيطة | بناء توقعات تدريجية بدون تعقيد رياضي |
# | اليوم الرابع | التقييم والتقرير والمشروع | اختيار أفضل نموذج وتحويل النتائج إلى قرار |

# %% [markdown]
# # اليوم الأول — Python Side / جانب Python قبل السلاسل الزمنية
#
# هذا هو الجزء الذي كان يجب أن يكون واضحاً من البداية.
# قبل أن نقرأ بيانات أو نبني نموذج تنبؤ، سنفهم أساسيات Python التي سنستخدمها فقط في هذه الدورة.
#
# **قاعدة اليوم:** لا نحفظ الكود، بل نفهم ماذا يفعل كل سطر.

# %% [markdown]
# ## Part 0: Jupyter Notebook Warm-up [10%]
#
# الغرض من هذا الجزء هو معرفة كيفية استخدام الدفتر: تشغيل خلية، قراءة الناتج، حفظ العمل، وفهم رسالة الخطأ.

# %% [markdown]
# ### 0.1 أول أمر Python
#
#     اكتب أمراً يطبع رسالة قصيرة للتأكد أن Python يعمل.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم أمر الطباعة.
# - اكتب جملة مثل: Python is working.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
print('Python is working')

# %% [markdown]
# ### 0.2 التعليقات في Python
#
#     التعليق هو نص يساعدنا على فهم الكود ولا يتم تنفيذه.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب تعليقاً في السطر الأول.
# - ثم اكتب أمر طباعة في السطر الثاني.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# This is a comment
print('We use comments to explain the code')

# %% [markdown]
# ### 0.3 خطأ بسيط مقصود
#
#     سنكتب خطأ بسيطاً لنتعلم قراءة رسائل الخطأ بدون خوف.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب أمر طباعة ناقصاً مع المدرب.
# - شاهد مكان الخطأ في الرسالة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Intentional error example
# print('Missing parenthesis')
print('Now the error is fixed')

# %% [markdown]
# ### 0.4 ترتيب تشغيل الخلايا
#
#     أنشئ متغيراً في خلية، ثم استخدمه في خلية أخرى. هذا يوضح أهمية تشغيل الخلايا بالترتيب.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - عرّف متغيراً اسمه course_name.
# - اطبعه في السطر التالي.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
course_name = 'Time Series Forecasting'
print(course_name)

# %% [markdown]
# ## Part 1: Python Basics for Forecasting [20%]
#
# سنستخدم أمثلة مبيعات بسيطة حتى يشعر المتدرب أن Python ليس موضوعاً منفصلاً عن الدورة.

# %% [markdown]
# ### 1.1 متغير لمبيعات اليوم
#
#     المتغير يحفظ قيمة نحتاج استخدامها لاحقاً.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ متغيراً اسمه sales_today.
# - ضع فيه رقماً يمثل مبيعات اليوم.
# - اطبع المتغير.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
sales_today = 120
print(sales_today)

# %% [markdown]
# ### 1.2 متغيران وحساب الفرق
#
#     نقارن مبيعات اليوم مع مبيعات الأمس.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ sales_today و sales_yesterday.
# - احسب الفرق بينهما.
# - اطبع الفرق.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
sales_today = 120
sales_yesterday = 100
difference = sales_today - sales_yesterday
print(difference)

# %% [markdown]
# ### 1.3 نسبة التغير
#
#     النسبة تساعدنا على فهم حجم التغير مقارنة بقيمة الأمس.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - احسب الفرق.
# - اقسم الفرق على مبيعات الأمس.
# - اضرب الناتج في 100.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
sales_today = 120
sales_yesterday = 100
change_percent = ((sales_today - sales_yesterday) / sales_yesterday) * 100
print(change_percent)

# %% [markdown]
# ### 1.4 النصوص Strings
#
#     النصوص تستخدم لحفظ أسماء المنتجات أو الفروع أو الأيام.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ متغيراً باسم product_name.
# - ضع داخله اسم منتج.
# - اطبع الجملة مع اسم المنتج.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
product_name = 'Coffee'
print('Best product:', product_name)

# %% [markdown]
# ### 1.5 قائمة مبيعات أسبوع
#
#     القائمة تحفظ عدة قيم في متغير واحد.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قائمة فيها 7 أرقام.
# - كل رقم يمثل مبيعات يوم.
# - اطبع القائمة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
week_sales = [100, 120, 115, 130, 150, 170, 160]
print(week_sales)

# %% [markdown]
# ### 1.6 الوصول لقيمة من القائمة
#
#     نتعلم كيف نأخذ أول يوم وآخر يوم من قائمة المبيعات.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اطبع أول قيمة في القائمة.
# - اطبع آخر قيمة في القائمة.
# - تذكر أن العد في Python يبدأ من صفر.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
week_sales = [100, 120, 115, 130, 150, 170, 160]
print('First day:', week_sales[0])
print('Last day:', week_sales[-1])

# %% [markdown]
# ### 1.7 مجموع ومتوسط الأسبوع
#
#     هذه خطوة بسيطة لكنها مهمة قبل التنبؤ.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - احسب مجموع المبيعات.
# - احسب عدد الأيام.
# - احسب المتوسط.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
week_sales = [100, 120, 115, 130, 150, 170, 160]
total_sales = sum(week_sales)
average_sales = total_sales / len(week_sales)
print('Total:', total_sales)
print('Average:', average_sales)

# %% [markdown]
# ### 1.8 أعلى وأقل مبيعات
#
#     نستخدم min و max لفهم نطاق البيانات.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم max لمعرفة أعلى قيمة.
# - استخدم min لمعرفة أقل قيمة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
week_sales = [100, 120, 115, 130, 150, 170, 160]
print('Highest:', max(week_sales))
print('Lowest:', min(week_sales))

# %% [markdown]
# ### 1.9 القيم الفريدة باستخدام Set
#
#     Set يساعدنا على معرفة القيم المختلفة بدون تكرار.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قائمة أيام فيها تكرار.
# - حوّلها إلى set.
# - اطبع الناتج.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
days = ['Sun', 'Mon', 'Mon', 'Tue', 'Wed', 'Wed']
unique_days = set(days)
print(unique_days)

# %% [markdown]
# ### 1.10 Dictionary بسيط
#
#     القاموس يربط اسم الشيء بقيمته، مثل المنتج وعدد المبيعات.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قاموساً فيه منتجات ومبيعاتها.
# - اطبع مبيعات منتج محدد.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
product_sales = {'Coffee': 120, 'Tea': 80, 'Cake': 45}
print(product_sales['Coffee'])

# %% [markdown]
# ## Part 2: Libraries — Pandas, NumPy, Matplotlib [20%]
#
# في Python لا نكتب كل شيء من الصفر. نستخدم مكتبات جاهزة:
#
# - **NumPy:** عمليات رقمية.
# - **Pandas:** جداول وملفات CSV.
# - **Matplotlib:** رسوم بيانية.

# %% [markdown]
# ### 2.1 استدعاء المكتبات
#
#     قبل استخدام أي مكتبة يجب استدعاؤها.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استدعِ pandas باسم pd.
# - استدعِ numpy باسم np.
# - استدعِ matplotlib.pyplot باسم plt.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.2 NumPy Array
#
#     نحوّل قائمة Python إلى array حتى تصبح العمليات الحسابية أسهل.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قائمة مبيعات.
# - حوّلها إلى numpy array.
# - اضرب القيم في 1.05 لمحاكاة زيادة 5%.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
import numpy as np
sales = [100, 120, 115, 130]
sales_array = np.array(sales)
new_sales = sales_array * 1.05
print(new_sales)

# %% [markdown]
# ### 2.3 إنشاء جدول Pandas
#
#     DataFrame هو جدول داخل Python.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قاموساً فيه day و sales.
# - حوّله إلى DataFrame.
# - اعرض الجدول.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
import pandas as pd
data = {'day': ['Sun', 'Mon', 'Tue'], 'sales': [100, 120, 115]}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### 2.4 معرفة الصفوف والأعمدة
#
#     بعد إنشاء الجدول نريد معرفة حجمه وأسماء أعمدته.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اعرض shape.
# - اعرض columns.
# - اعرض أول 3 صفوف.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
print(df.shape)
print(df.columns)
df.head(3)

# %% [markdown]
# ### 2.5 اختيار عمود واحد
#
# نختار عموداً محدداً من الجدول.
#
# **المطلوب من الطالب داخل خلية الكود الفارغة:**
# - اطبع عمود sales فقط.
#
# **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
print(df['sales'])

# %% [markdown]
# ### 2.6 تصفية الصفوف
#
# نختار الصفوف التي تحقق شرطاً معيناً.
#
# **المطلوب من الطالب داخل خلية الكود الفارغة:**
# - اعرض الأيام التي مبيعاتها أكبر من 110.
#
# **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
high_sales = df[df['sales'] > 110]
high_sales

# %% [markdown]
# ### 2.7 إضافة عمود جديد
#
#     نضيف عموداً يوضح هل اليوم عالي المبيعات أم لا.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ عموداً جديداً اسمه high_sales.
# - القيمة True إذا كانت المبيعات أكبر من 110.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df['high_sales'] = df['sales'] > 110
df

# %% [markdown]
# ## Part 3: Visualization — الرسم البياني [20%]
#
# الرسم يساعدنا على رؤية النمط قبل بناء أي نموذج تنبؤ.

# %% [markdown]
# ### 3.1 رسم خطي للمبيعات الأسبوعية
#
#     الرسم الخطي مناسب للسلاسل الزمنية لأنه يوضح التغير مع الزمن.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قائمة أيام وقائمة مبيعات.
# - استخدم plt.plot.
# - أضف عنواناً وتسميات للمحاور.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
import matplotlib.pyplot as plt
days = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
sales = [100, 120, 115, 130, 150, 170, 160]
plt.plot(days, sales, marker='o')
plt.title('Weekly Sales')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### 3.2 Bar Chart للمنتجات
#
#     الرسم العمودي مناسب لمقارنة منتجات أو فروع.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ أسماء المنتجات.
# - أنشئ مبيعات المنتجات.
# - استخدم plt.bar.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
products = ['Coffee', 'Tea', 'Cake']
sales = [120, 80, 45]
plt.bar(products, sales)
plt.title('Sales by Product')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### 3.3 Histogram لتوزيع المبيعات
#
#     الهيستوغرام يوضح كيف تتوزع القيم: هل معظمها منخفضة أم عالية؟
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قائمة مبيعات كثيرة.
# - استخدم plt.hist.
# - أضف عنواناً.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
sales = [90, 100, 110, 115, 120, 122, 130, 150, 160, 170, 180, 190]
plt.hist(sales, bins=5)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3.4 Scatter Plot بين الزبائن والمبيعات
#
#     نستخدم Scatter لمعرفة العلاقة بين متغيرين.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ قائمة عدد الزبائن.
# - أنشئ قائمة المبيعات.
# - استخدم plt.scatter.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
customers = [20, 25, 30, 35, 40, 45]
sales = [100, 120, 130, 150, 170, 190]
plt.scatter(customers, sales)
plt.title('Customers vs Sales')
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Part 4: Reading CSV — الانتقال من أمثلة صغيرة إلى بيانات حقيقية [20%]
#
# الآن نبدأ باستخدام ملف بيانات فعلي خاص بالدورة.

# %% [markdown]
# ### 4.1 قراءة ملف CSV
#
#     نستخدم Pandas لقراءة ملف البيانات الخام.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم pd.read_csv.
# - احفظ البيانات في متغير df.
# - اعرض أول 5 صفوف.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
import pandas as pd
df = pd.read_csv('cafe_sales_timeseries_course_raw.csv')
df.head()

# %% [markdown]
# ### 4.2 معلومات عامة عن الجدول
#
#     نريد معرفة عدد الصفوف والأعمدة وأسماء الأعمدة.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم shape.
# - استخدم columns.
# - استخدم info.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
print(df.shape)
print(df.columns)
df.info()

# %% [markdown]
# ### 4.3 وصف رقمي سريع
#
#     describe يعطينا ملخصاً للأعمدة الرقمية.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم describe.
# - لاحظ المتوسط والحد الأدنى والحد الأعلى.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df.describe()

# %% [markdown]
# ### 4.4 سؤال تحليلي سريع
#
#     اكتب كوداً يطبع أعلى قيمة مبيعات في الملف.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اختر عمود sales.
# - استخدم max.
# - اطبع الناتج.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
print(df['sales'].max())

# %% [markdown]
# # اليوم الثاني — تجهيز السلسلة الزمنية وتنظيفها
#
# في هذا اليوم سننتقل من جدول عادي إلى سلسلة زمنية جاهزة للتحليل.

# %% [markdown]
# ### 5.1 تحويل التاريخ إلى datetime
#
#     عمود التاريخ يجب أن يتحول إلى نوع زمني حتى يفهمه Python كسلسلة زمنية.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم pd.to_datetime.
# - حوّل عمود date.
# - اعرض نوع العمود بعد التحويل.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df['date'] = pd.to_datetime(df['date'])
print(df['date'].dtype)

# %% [markdown]
# ### 5.2 ترتيب البيانات حسب التاريخ
#
#     السلاسل الزمنية يجب أن تكون مرتبة زمنياً.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - رتب df حسب date.
# - اعرض أول 5 صفوف.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df = df.sort_values('date')
df.head()

# %% [markdown]
# ### 5.3 جعل التاريخ هو الفهرس
#
#     الفهرس الزمني يسهل الرسم والتجميع حسب الوقت.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم set_index.
# - اعرض أول 5 صفوف.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df = df.set_index('date')
df.head()

# %% [markdown]
# ### 5.4 رسم المبيعات اليومية
#
#     نرسم السلسلة الزمنية لنرى الاتجاه العام.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم plot على عمود sales.
# - أضف عنواناً.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df['sales'].plot(figsize=(10,4), title='Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### 5.5 فحص القيم المفقودة
#
#     القيم المفقودة قد تؤثر على النماذج.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم isna.
# - استخدم sum.
# - اطبع عدد القيم المفقودة لكل عمود.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
print(df.isna().sum())

# %% [markdown]
# ### 5.6 تعبئة القيم المفقودة
#
#     طريقة بسيطة: تعبئة القيمة المفقودة بمتوسط العمود أو بالقيمة السابقة.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - انسخ df إلى df_clean.
# - املأ القيم المفقودة في sales بالمتوسط.
# - تأكد أن القيم المفقودة أصبحت صفر.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df_clean = df.copy()
df_clean['sales'] = df_clean['sales'].fillna(df_clean['sales'].mean())
print(df_clean['sales'].isna().sum())

# %% [markdown]
# ### 5.7 فحص التواريخ المكررة
#
#     التكرار في التاريخ قد يربك التحليل.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم index.duplicated.
# - احسب عدد التكرارات.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
duplicate_dates = df_clean.index.duplicated().sum()
print(duplicate_dates)

# %% [markdown]
# ### 5.8 معالجة التواريخ المكررة
#
#     إذا وجدنا تاريخاً مكرراً، يمكن تجميعه بأخذ المتوسط.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم groupby على الفهرس.
# - احسب المتوسط لكل تاريخ.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df_clean = df_clean.groupby(df_clean.index).mean(numeric_only=True)
df_clean.head()

# %% [markdown]
# ### 5.9 اكتشاف القيم الشاذة بطريقة بسيطة
#
#     سنستخدم قاعدة تقريبية: القيم الأعلى من حد معين قد تكون شاذة.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - احسب quantile 0.99.
# - اطبع الأيام التي تتجاوز هذا الحد.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
limit = df_clean['sales'].quantile(0.99)
outliers = df_clean[df_clean['sales'] > limit]
outliers

# %% [markdown]
# ### 5.10 تقليل أثر القيم الشاذة
#
#     بدلاً من حذفها، يمكن قصها عند حد أعلى.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم clip.
# - ارسم قبل وبعد إذا أردت.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
upper_limit = df_clean['sales'].quantile(0.99)
df_clean['sales_capped'] = df_clean['sales'].clip(upper=upper_limit)
df_clean[['sales', 'sales_capped']].plot(figsize=(10,4))
plt.show()

# %% [markdown]
# ### 5.11 المتوسط المتحرك 7 أيام
#
#     المتوسط المتحرك يخفف الضجيج ويظهر الاتجاه العام.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ عمود rolling_7.
# - استخدم rolling(7).mean().
# - ارسم المبيعات والمتوسط المتحرك.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df_clean['rolling_7'] = df_clean['sales_capped'].rolling(7).mean()
df_clean[['sales_capped', 'rolling_7']].plot(figsize=(10,4))
plt.show()

# %% [markdown]
# ### 5.12 تجميع أسبوعي
#
#     أحياناً نحتاج النظر إلى إجمالي المبيعات كل أسبوع.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم resample('W').sum().
# - ارسم الناتج.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
weekly_sales = df_clean['sales_capped'].resample('W').sum()
weekly_sales.plot(figsize=(10,4), title='Weekly Total Sales')
plt.show()

# %% [markdown]
# ### 5.13 تحليل أيام الأسبوع
#
#     نفهم هل بعض الأيام أعلى من غيرها.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ عمود day_name.
# - استخدم groupby.
# - احسب متوسط المبيعات لكل يوم.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
df_clean['day_name'] = df_clean.index.day_name()
day_average = df_clean.groupby('day_name')['sales_capped'].mean()
day_average

# %% [markdown]
# # اليوم الثالث — نماذج التنبؤ البسيطة
#
# لا نبدأ بنموذج معقد. نبدأ بنماذج سهلة حتى يفهم المتدرب معنى التنبؤ.

# %% [markdown]
# ### 6.1 تقسيم البيانات Train/Test زمنياً
#
#     في السلاسل الزمنية لا نخلط البيانات عشوائياً. الماضي للتدريب، والمستقبل للاختبار.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - حدد test_size = 14.
# - اجعل train كل البيانات عدا آخر 14 يوم.
# - اجعل test آخر 14 يوم.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
series = df_clean['sales_capped']
test_size = 14
train = series.iloc[:-test_size]
test = series.iloc[-test_size:]
print(train.shape, test.shape)

# %% [markdown]
# ### 6.2 نموذج آخر قيمة Last Value
#
#     أبسط نموذج: نتوقع أن الأيام القادمة تشبه آخر قيمة معروفة.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - خذ آخر قيمة من train.
# - كررها بعدد أيام test.
# - حوّلها إلى Series بنفس فهرس test.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
last_value = train.iloc[-1]
forecast_last = pd.Series(last_value, index=test.index)
forecast_last.head()

# %% [markdown]
# ### 6.3 نموذج متوسط آخر 7 أيام
#
#     بدلاً من آخر يوم فقط، نستخدم متوسط آخر أسبوع.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - احسب متوسط آخر 7 قيم من train.
# - كرر المتوسط لأيام test.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
avg_7 = train.tail(7).mean()
forecast_avg7 = pd.Series(avg_7, index=test.index)
forecast_avg7.head()

# %% [markdown]
# ### 6.4 نموذج نفس اليوم من الأسبوع السابق
#
#     إذا كانت البيانات أسبوعية النمط، نقول إن هذا الاثنين يشبه الاثنين السابق.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - خذ آخر 7 قيم من train.
# - كررها حتى تغطي test.
# - اجعل الفهرس مثل test.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
last_week = train.tail(7).values
forecast_values = list(last_week) * 2
forecast_weekly = pd.Series(forecast_values[:len(test)], index=test.index)
forecast_weekly.head()

# %% [markdown]
# ### 6.5 نموذج المتوسط المتحرك
#
#     نستخدم متوسط نافذة متحركة كفكرة بسيطة للتوقع.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - احسب متوسط آخر 14 يوم.
# - كرر الناتج لفترة الاختبار.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
moving_avg = train.tail(14).mean()
forecast_moving = pd.Series(moving_avg, index=test.index)
forecast_moving.head()

# %% [markdown]
# ### 6.6 نموذج Holt-Winters مبسط
#
#     هذا النموذج أقوى قليلاً لأنه يحاول فهم الاتجاه والموسمية.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استدعِ ExponentialSmoothing.
# - استخدم seasonal_periods=7.
# - توقع عدد أيام test.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
model_hw = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=7).fit()
forecast_hw = model_hw.forecast(len(test))
forecast_hw.head()

# %% [markdown]
# ### 6.7 رسم Actual vs Forecast
#
#     نقارن التوقع بالقيم الحقيقية بصرياً.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - ارسم test.
# - ارسم forecast_last و forecast_avg7 و forecast_weekly.
# - أضف legend.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
plt.figure(figsize=(10,4))
plt.plot(test.index, test.values, label='Actual')
plt.plot(forecast_last.index, forecast_last.values, label='Last Value')
plt.plot(forecast_avg7.index, forecast_avg7.values, label='Average 7 Days')
plt.plot(forecast_weekly.index, forecast_weekly.values, label='Weekly Naive')
plt.legend()
plt.title('Actual vs Forecast')
plt.show()

# %% [markdown]
# # اليوم الرابع — تقييم النماذج والتقرير النهائي
#
# التنبؤ وحده لا يكفي. يجب أن نقيس الخطأ ونختار النموذج الأفضل ثم نحول النتيجة إلى قرار.

# %% [markdown]
# ### 7.1 دالة MAE
#
#     MAE يقيس متوسط الخطأ المطلق. كلما كان أقل كان النموذج أفضل.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استدعِ mean_absolute_error.
# - احسب MAE لنموذج Last Value.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
from sklearn.metrics import mean_absolute_error
mae_last = mean_absolute_error(test, forecast_last)
print(mae_last)

# %% [markdown]
# ### 7.2 دالة RMSE
#
#     RMSE يعطي وزناً أكبر للأخطاء الكبيرة.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استدعِ mean_squared_error.
# - احسب الجذر التربيعي للـ MSE.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
from sklearn.metrics import mean_squared_error
rmse_last = mean_squared_error(test, forecast_last) ** 0.5
print(rmse_last)

# %% [markdown]
# ### 7.3 دالة MAPE مبسطة
#
#     MAPE يعرض الخطأ كنسبة مئوية.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - عرّف دالة mape.
# - احسب MAPE لنموذج Last Value.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
def mape(actual, predicted):
    return (abs((actual - predicted) / actual).mean()) * 100

mape_last = mape(test, forecast_last)
print(mape_last)

# %% [markdown]
# ### 7.4 مقارنة كل النماذج
#
#     نضع النتائج في جدول واحد لتسهيل اختيار الأفضل.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ دالة evaluate.
# - طبّقها على النماذج.
# - اعرض جدول المقارنة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
def evaluate_model(name, actual, predicted):
    return {
        'model': name,
        'MAE': mean_absolute_error(actual, predicted),
        'RMSE': mean_squared_error(actual, predicted) ** 0.5,
        'MAPE': mape(actual, predicted)
    }

results = [
    evaluate_model('Last Value', test, forecast_last),
    evaluate_model('Average 7 Days', test, forecast_avg7),
    evaluate_model('Weekly Naive', test, forecast_weekly),
    evaluate_model('Moving Average', test, forecast_moving),
    evaluate_model('Holt-Winters', test, forecast_hw)
]
results_df = pd.DataFrame(results)
results_df

# %% [markdown]
# ### 7.5 اختيار أفضل نموذج
#
#     أفضل نموذج هو الأقل في MAE في هذا التدريب.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - رتب جدول النتائج حسب MAE.
# - اعرض أول صف.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
best_model = results_df.sort_values('MAE').iloc[0]
best_model

# %% [markdown]
# ### 7.6 توقع 14 يوماً قادمة
#
#     نستخدم نموذجاً بسيطاً لإنشاء توقع مستقبلي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - أنشئ future_dates.
# - استخدم متوسط آخر 7 أيام كتوقع بسيط.
# - اعرض جدول التوقع.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
future_dates = pd.date_range(series.index.max() + pd.Timedelta(days=1), periods=14, freq='D')
future_value = series.tail(7).mean()
future_forecast = pd.DataFrame({'date': future_dates, 'forecast_sales': future_value})
future_forecast

# %% [markdown]
# ### 7.7 رسم التوقع القادم
#
#     نعرض آخر 30 يوم مع توقع 14 يوم قادم.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - ارسم آخر 30 يوم من البيانات.
# - ارسم توقع المستقبل.
# - أضف legend.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
plt.figure(figsize=(10,4))
plt.plot(series.tail(30).index, series.tail(30).values, label='Last 30 Days')
plt.plot(future_forecast['date'], future_forecast['forecast_sales'], label='Next 14 Days Forecast')
plt.legend()
plt.title('Future Forecast')
plt.show()

# %% [markdown]
# ### 7.8 توصية عملية
#
#     نحوّل الرقم إلى قرار بسيط يفهمه غير التقنيين.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - احسب متوسط التوقع.
# - اطبع توصية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
avg_forecast = future_forecast['forecast_sales'].mean()
print('Expected average daily sales:', round(avg_forecast, 2))
print('Recommendation: prepare stock and staff based on the expected daily demand.')

# %% [markdown]
# ### 7.9 تصدير التقرير إلى Excel
#
#     نحفظ النتائج حتى يمكن مشاركتها مع الإدارة أو الفريق.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - استخدم ExcelWriter.
# - ضع جدول المقارنة في Sheet.
# - ضع توقع المستقبل في Sheet آخر.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
with pd.ExcelWriter('time_series_student_report.xlsx') as writer:
    results_df.to_excel(writer, sheet_name='Model Comparison', index=False)
    future_forecast.to_excel(writer, sheet_name='Future Forecast', index=False)

print('Report exported successfully')

# %% [markdown]
# # Final Mini Project — مشروع تطبيقي مصغر
#
# ## المطلوب
#
# استخدم البيانات النظيفة لتنفيذ مشروع صغير:
#
# 1. قراءة البيانات.
# 2. تحويل التاريخ إلى datetime.
# 3. رسم المبيعات.
# 4. تقسيم البيانات إلى Train/Test.
# 5. بناء نموذجين على الأقل.
# 6. حساب MAE لكل نموذج.
# 7. اختيار النموذج الأفضل.
# 8. توقع 14 يوماً قادمة.
# 9. كتابة 3 توصيات عملية.
# 10. تصدير تقرير Excel.
#
# **ملاحظة للطلاب:** نفذوا المشروع خطوة خطوة. لا تنتقلوا إلى الخطوة التالية قبل فهم ناتج الخطوة الحالية.

# %% [markdown]
# ### Project Step 1: قراءة البيانات النظيفة
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 2: تحويل التاريخ وترتيب البيانات
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 3: رسم المبيعات
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 4: تقسيم Train/Test
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 5: بناء النموذج الأول
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 6: بناء النموذج الثاني
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 7: حساب MAE
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 8: اختيار الأفضل
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 9: توقع 14 يوم
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# ### Project Step 10: كتابة التوصيات وتصدير التقرير
#
#     نفّذ هذه الخطوة ضمن المشروع النهائي.
#
#     **المطلوب من الطالب داخل خلية الكود الفارغة:**
#     - اكتب الكود مع المدرب أو ضمن المجموعة.
# - اعرض الناتج بوضوح.
# - اكتب ملاحظة تفسيرية قصيرة.
#
#     **ماذا نلاحظ بعد التشغيل؟** اكتب ملاحظة قصيرة بعد ظهور الناتج.

# %%
# Project solution will depend on student choices
print('Complete this step based on the project instructions')

# %% [markdown]
# # Appendix — أخطاء شائعة
#
# | الخطأ | السبب المحتمل | الحل |
# |---|---|---|
# | FileNotFoundError | ملف CSV ليس في نفس المجلد | ضع الملف بجانب الدفتر أو صحح المسار |
# | NameError | استخدمت متغيراً قبل تعريفه | شغّل الخلايا بالترتيب |
# | KeyError | اسم العمود غير صحيح | افحص `df.columns` |
# | ValueError في التاريخ | صيغة التاريخ غير مفهومة | استخدم `pd.to_datetime` وتحقق من القيم |
# | الرسم لا يظهر | لم تستخدم `plt.show()` أحياناً | أضف `plt.show()` |
